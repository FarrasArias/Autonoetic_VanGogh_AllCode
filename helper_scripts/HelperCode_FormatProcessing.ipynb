# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/SFU/STeve/DocsToExtractData/letters_chunks_processed_expert.csv", index_col=0)

df.reset_index(drop=True)

df = df.iloc[0:862]

# %%
df["timestamp"] = pd.to_datetime(df["date"])

# %%
df.head()

# %% [markdown]
# #1. Data Parsing (Characters and Relevance)

# %%
import re

keywords = ["Emotions", "Characters", "Context", "Relevance", "Paintings", "Comment"]

def extract_text_after_keyword(text, keyword, next_keyword):
    try:
        # Make the 's' in 'Comments' optional and include a lookahead to ensure it stops at 'Comment'
        if keyword == "Comment":
            keyword = "Comments?"
        if next_keyword == "Comment":
            next_keyword = "Comments?"

        pattern = rf"{keyword}:\s*(.*?)(?=\s*{next_keyword}:|$)"
        match = re.search(pattern, text, re.DOTALL)
        if match:
            return match.group(1).strip()
        return ""
    except Exception as e:
        print(f"Error processing keyword '{keyword}': {e}")
        print(text)
        return ""


for index, row in df.iterrows():
    for i, keyword in enumerate(keywords):

        next_keyword = keywords[i + 1] if i + 1 < len(keywords) else None

        extracted_text = extract_text_after_keyword(row['Scene_Analysis'], keyword, next_keyword)

        df.at[index, keyword] = extracted_text

# %%
df

# %%
df.head()

# %%
df.iloc[0]["API_Response"]

# %%
def process_text(text):
    pattern = r"(NARRATOR \(V\.O\.?\))|(BACKGROUND)|(VINCENT VAN GOGH \(V\.O\.?\))"
    split_text = re.split(pattern, text)

    temp_dict = {'NARRATOR (V.O.)': '', 'BACKGROUND': '', 'VINCENT VAN GOGH (V.O.)': ''}
    key = None  # Initializing key

    for section in split_text:
        if section in temp_dict:
            key = section
        elif section and key:
            temp_dict[key] += section.strip() + " "

    return temp_dict

# %%
df.loc[910]

# %%
df["API_Response"] = df["API_Response"].fillna("No text")

processed_data = df['API_Response'].apply(process_text)

processed_df = pd.DataFrame(processed_data.tolist())

df.reset_index(inplace=True, drop=True)
processed_df.reset_index(inplace=True, drop=True)

df_expanded = pd.merge(df, processed_df, left_index=True, right_index=True)

df_expanded.head()

# %%
df_expanded.tail()

# %%
narrator_empty_count = (df_expanded['NARRATOR (V.O.)'] == "").sum()
background_empty_count = (df_expanded['BACKGROUND'] == "").sum()
vincent_empty_count = (df_expanded['VINCENT VAN GOGH (V.O.)'] == "").sum()

print("Empty 'NARRATOR (V.O.)' count:", narrator_empty_count)
print("Empty 'BACKGROUND' count:", background_empty_count)
print("Empty 'VINCENT VAN GOGH (V.O.)' count:", vincent_empty_count)

# %%
condition = (df_expanded['NARRATOR (V.O.)'] == "") | (df_expanded['BACKGROUND'] == "") | (df_expanded['VINCENT VAN GOGH (V.O.)'] == "")

sub_dataset = df_expanded.loc[condition]

print(sub_dataset.shape)
sub_dataset.head()
# Out:
# (33, 18)
#            file_name        date     origin sender receiver  \
# 7    008_V-T_008.pdf  1873-05-09        T-H    VvG      TvG
# 14   015_V-T_012.pdf  1873-11-19     London    VvG      TvG
# 114  117_V-T_102.pdf  1877-07-15  Amsterdam    VvG      TvG
# 126  129_V-T_114.pdf  1877-11-25  Amsterdam    VvG      TvG
# 177  186_V-T_164.pdf  1881-12-21      Etten    VvG      TvG
#
#                                                content  \
# 7    Letter 008\nThe Hague, 9th May 1873\nDear Theo...
# 14   Letter 012\nLondon, 19 November 1873\nDear The...
# 114  Letter 102\nAmsterdam, Sunday 15 July 1877\nDe...
# 126  Letter 114\nAmsterdam, 25 November 1877\nDear ...
# 177  Letter 164\nEtten, c. 21 December 1881\nSometi...
#
#                                           API_Response  \
# 7    NARRATOR (V.O.)\nIn 1873, an emotional unsettl...
# 14   NARRATOR (V.O)\nIn the cold winter of 1873, a ...
# 114  NARRATOR (V.O)\nWe are in the city of Amsterda...
# 126  NARRATOR (V.O.)\nIn November 1877, a desolate ...
# 177  NARRATOR (V.O.)\nVan Gogh, returning from Hagu...
#
#                                         Scene_Analysis  timestamp  \
# 7    Emotions:\n[Sorrowful, Unsettled]\n\nCharacter... 1873-05-09
# 14   Emotions:\n[Passion, Isolation, Longing, Conce... 1873-11-19
# 114  Emotions:\n[Yearning, Perseverance]\n\nCharact... 1877-07-15
# 126  Emotions:\n[Desolation, Melancholy]\n\nCharact... 1877-11-25
# 177  conversation with his brother, Theo. He feels ... 1881-12-21
#
#                                         Emotions  \
# 7                         [Sorrowful, Unsettled]
# 14   [Passion, Isolation, Longing, Concern, Joy]
# 114                     [Yearning, Perseverance]
# 126                     [Desolation, Melancholy]
# 177                       [Desolation, Disquiet]
#
#                                             Characters  \
# 7    [Van Gogh, Theo (mentioned), Mrs. Tersteeg (me...
# 14       [Vincent Van Gogh, Theo Van Gogh (mentioned)]
# 114  [Vincent Van Gogh, Theo(mentioned), Reverend M...
# 126  [Vincent Van Gogh, Theo Van Gogh(mentioned), B...
# 177                       [Van Gogh, Theo (mentioned)]
#
#                                                Context Relevance  \
# 7    This scene represents when Van Gogh was about ...         8
# 14   This scene happens in Van Gogh's young adult y...         7
# 114  This scene occurs when Van Gogh is a young man...         8
# 126  This scene depicts an isolated Van Gogh in Ams...         9
# 177  This scene occurs after Van Gogh has returned ...         7
#
#                                              Paintings  \
# 7                                               [None]
# 14                                              [None]
# 114  ['The Church at Auvers', 'View of the Sea at S...
# 126                                             [None]
# 177                   ["At Eternity's Gate", "Sorrow"]
#
#                                                Comment  \
# 7    The scene under review is crucial in understan...
# 14   This scene provides a deep insight into Vincen...
# 114  This pre-artistry phase of Van Gogh's life sig...
# 126  This scene is profound in its depiction of Van...
# 177  This scene reveals a key period in Van Gogh's ...
#
#                                        NARRATOR (V.O.)  \
# 7    In 1873, an emotional unsettled Van Gogh was t...
# 14
# 114
# 126  In November 1877, a desolate Vincent Van Gogh ...
# 177  Van Gogh, returning from Hague, is reflecting ...
#
#                                             BACKGROUND  \
# 7    May 9, 1873, a humble Dutch residence in The H...
# 14   :\nThe scene unfolds in a modest, dimly-lit ro...
# 114  It is Sunday morning. Rain falls softly on cob...
# 126  Twilight descends upon the city of Amsterdam. ...
# 177
#
#                                VINCENT VAN GOGH (V.O.)
# 7
# 14   Theo, Dear Brother, my days in London are fill...
# 114  Today, I left for service amidst rain, and whe...
# 126
# 177

# %%
sub_dataset.loc[177]["API_Response"]
# Out:
# 'NARRATOR (V.O.)\nVan Gogh, returning from Hague, is reflecting on a'

# %%
for number in list(sub_dataset.index):
  temp = process_text(sub_dataset.loc[number]["API_Response"])
  sub_dataset.loc[number, temp.keys()] = temp.values()

# %%
sub_dataset
# Out:
#             file_name        date     origin sender             receiver  \
# 7     008_V-T_008.pdf  1873-05-09        T-H    VvG                  TvG
# 14    015_V-T_012.pdf  1873-11-19     London    VvG                  TvG
# 114   117_V-T_102.pdf  1877-07-15  Amsterdam    VvG                  TvG
# 126   129_V-T_114.pdf  1877-11-25  Amsterdam    VvG                  TvG
# 177   186_V-T_164.pdf  1881-12-21      Etten    VvG                  TvG
# 179  188_V-C_165a.pdf  1881-01-01      Etten    VvG            Uncle Cor
# 191   201_V-T_177.pdf  1882-02-25        T-H    VvG                  TvG
# 198   208_V-T_184.pdf  1882-04-01        T-H    VvG                  TvG
# 202   212_V-T_188.pdf  1882-04-27        T-H    VvG                  TvG
# 210   216_V-T_195.pdf  1882-05-01        T-H    VvG                  TvG
# 263   285_V-T_248.pdf  1882-11-27        T-H    VvG                  TvG
# 269   291_V-T_254.pdf  1882-12-21        T-H    VvG                  TvG
# 299   334_V-T_283.pdf  1883-05-06        T-H    VvG                  TvG
# 313   352_V-T_297.pdf  1883-07-02        T-H    VvG                  TvG
# 325   365_V-T_309.pdf  1883-08-08        T-H    VvG                  TvG
# 395   442_V-T_371.pdf  1884-06-01         Nu    VvG                  TvG
# 396   443_V-T_372.pdf  1884-07-01         Nu    VvG                  TvG
# 456   518_V-T_425.pdf  1885-09-04         Nu    VvG                  TvG
# 458   520_V-T_427.pdf  1885-10-01         Nu    VvG                  TvG
# 545   616_V-T_508.pdf  1888-06-29         Ar    VvG                  TvG
# 573   658_V-T_535.pdf  1888-09-12         Ar    VvG                  TvG
# 581  666_V-T_541a.pdf  1888-09-26         Ar    VvG                  TvG
# 667   785_V-T_615.pdf  1889-11-21        S-R    VvG                  TvG
# 670   786_V-T_618.pdf  1889-12-07        S-R    VvG                  TvG
# 676   801_V-T_623.pdf  1890-01-15        S-R    VvG                  TvG
# 758   299_V-R_R23.pdf  1883-01-20        T-H    VvG   Anthon van Rappard
# 771   340_V-R_R36.pdf  1883-05-25        T-H    VvG   Anthon van Rappard
# 797   689_T-V_T02.pdf  1888-10-23      Paris    TvG                  VvG
# 823   806_T-V_T27.pdf  1890-01-31      Paris    TvG                  VvG
# 835   852_T-V_T39.pdf  1890-06-30      Paris    TvG                  VvG
# 840    562_V-W_W2.pdf  1888-02-28         Ar    VvG  Wilhelmina van Gogh
# 841    571_V-W_W3.pdf  1888-03-30         Ar    VvG  Wilhelmina van Gogh
# 858   813_V-W_W20.pdf  1890-02-20        S-R    VvG  Wilhelmina van Gogh
#
#                                                content  \
# 7    Letter 008\nThe Hague, 9th May 1873\nDear Theo...
# 14   Letter 012\nLondon, 19 November 1873\nDear The...
# 114  Letter 102\nAmsterdam, Sunday 15 July 1877\nDe...
# 126  Letter 114\nAmsterdam, 25 November 1877\nDear ...
# 177  Letter 164\nEtten, c. 21 December 1881\nSometi...
# 179  Letter 165a\nEtten\nDear Uncle,\nAs Theo is go...
# 191  Letter 177\nThe Hague, Saturday 25 February 18...
# 198  Letter 184\nThe Hague, early April, 1882\nDear...
# 202  Letter 188\nThe Hague, c. 15 – 27 April 1882\n...
# 210  Letter 195\nThe Hague, 1 May 1882\nDear Theo,\...
# 263  Letter 248\nThe Hague, 26 and 27 November 1882...
# 269  Letter 254\nThe Hague, c. 21 December 1882\nDe...
# 299  Letter 283\nThe Hague, c. 4 – 6 May 1883\nDear...
# 313  Letter 297\nThe Hague, c. 2 July 1883\nDear Th...
# 325  Letter 309\nThe Hague, c. 4 – 8 August 1883\nD...
# 395  Letter 371\nNuenen, early June 1884\nDear Theo...
# 396  Letter 372\nNuenen, early July 1884\nDear Theo...
# 456  Letter 425\nNuenen c. 4 September 1885\nDear T...
# 458  Letter 427\nNuenen, October 1885\nDear Theo,\n...
# 545  Letter 508\nArles, 5 July 1888\nMy dear Theo,\...
# 573  Letter 535\nArles, 12th September 1888\nMy dea...
# 581  Letter 541a\nArles, c. 26 September 1888\nDear...
# 667  Letter 615\nSaint-Rémy, c. 21 November 1889\nM...
# 670  Letter 618\nSaint-Rémy, 7 December 1889\nMy de...
# 676  Letter 623\nSt.-Rémy, c. 12 – 15 January 1890\...
# 758  Letter R23\nThe Hague, c. 20 January 1883\nAmi...
# 771  Letter R36\nThe Hague, c. 25 May 1883\nAmice R...
# 797  Letter T 2\nParis, 23 October 1888\nMy dear Vi...
# 823  Letter T27\nParis, 31 January 1890\nMy dear Vi...
# 835  Letter T39\nParis, 30 June or 1 July 1890\nMy ...
# 840  Letter W02\nArles, c. 28 February 1888\nDear S...
# 841  W3\nArles, 30 March 1888\nDear Sister,\nIn ord...
# 858  W20 1\nSaint-Rémy, c. 20 February 1890\nMy Dea...
#
#                                           API_Response  \
# 7    NARRATOR (V.O.)\nIn 1873, an emotional unsettl...
# 14   NARRATOR (V.O)\nIn the cold winter of 1873, a ...
# 114  NARRATOR (V.O)\nWe are in the city of Amsterda...
# 126  NARRATOR (V.O.)\nIn November 1877, a desolate ...
# 177  NARRATOR (V.O.)\nVan Gogh, returning from Hagu...
# 179  NARRATOR (V.O)\nAt this time in Vincent van Go...
# 191  NARRATOR (V.O)\nThe year is 1882. We find ours...
# 198  NARRATOR (V.O.)\nWe are now in The Hague, in e...
# 202  NARRATOR (V.O)\nIn a turbulent time of Van Gog...
# 210  NARRATOR (V.O)\nWe find ourselves in the heart...
# 263  NARRATOR (V.O.)\nAs we move into late 1882, wi...
# 269  NARRATOR (V.O)\nAt the height of his artistic ...
# 299  NARRATOR (V.O)\nDuring the spring of 1883, Van...
# 313  NARRATOR (V.O)\nIn the summer of 1883, Vincent...
# 325  NARRATOR (V.O)\nIn the summer of 1883, Vincent...
# 395  NARRATOR (V.O.)\nIn the early June of 1884, Vi...
# 396  NARRATOR (V.O.)\nIn the summer of 1884, Vincen...
# 456  NARRATOR(V.O.)\nWe're in Nuenen, September 188...
# 458  NARRATOR (V.O)\nDuring October 1885, in Nuenen...
# 545  NARRATOR (V.O)\nIn the summer of 1888, Van Gog...
# 573  NARRATOR (V.O.)\nVan Gogh, residing in Arles i...
# 581  NARRATOR (V.O.)\nAs autumn set in 1888 in Arle...
# 667  NARRATOR (V.O)\nWe find Vincent van Gogh in th...
# 670  NARRATOR (V.O.)\nWe are now pulled into the wo...
# 676  NARRATOR (V.O.)\nIn the winter of 1890, Vincen...
# 758  NARRATOR (V.O)\nIn the winter of 1883, in The ...
# 771  NARRATOR (V.O)\nIn 1883, Vincent van Gogh was ...
# 797  NARRATOR (V.O.)\nIn the autumn of 1888, Vincen...
# 823  NARRATOR (V.O.)\nIn the winter of 1890, Vincen...
# 835  NARRATOR (V.O) \nThis particular moment takes ...
# 840  NARRATOR (V.O.)\nVincent van Gogh, a passionat...
# 841  NARRATOR (V.O.)\nIn the year 1888, a deeply in...
# 858  NARRATOR (V.O)\nIn February 1890, post-impress...
#
#                                         Scene_Analysis  timestamp  \
# 7    Emotions:\n[Sorrowful, Unsettled]\n\nCharacter... 1873-05-09
# 14   Emotions:\n[Passion, Isolation, Longing, Conce... 1873-11-19
# 114  Emotions:\n[Yearning, Perseverance]\n\nCharact... 1877-07-15
# 126  Emotions:\n[Desolation, Melancholy]\n\nCharact... 1877-11-25
# 177  conversation with his brother, Theo. He feels ... 1881-12-21
# 179  Emotions:\n[Isolation, Yearning]\n\nCharacters... 1881-01-01
# 191  Emotions:\n[Anticipation, Anxiety]\n\nCharacte... 1882-02-25
# 198  Emotions:\n[Desolation, Introspection, Anxiety... 1882-04-01
# 202  Emotions:\n[Anxiety, Determination]\n\nCharact... 1882-04-27
# 210  Emotions:\n[Struggle, Passion, Longing, Relief... 1882-05-01
# 263  Emotions:\n[Struggle, Hopefulness]\n\nCharacte... 1882-11-27
# 269  Emotions:\n[Isolation, Longing]\n\nCharacters:... 1882-12-21
# 299  Emotions:\n[Uncertainty, Loneliness]\n\nCharac... 1883-05-06
# 313  Emotions:\n[Struggle, Passion, Isolation, Dete... 1883-07-02
# 325  Emotions:\n[Passionate, Restless, Hopeful, Ner... 1883-08-08
# 395  Emotions:\n[Preoccupied, Contemplative]\n\nCha... 1884-06-01
# 396  Emotions:\n[Passion, Gratitude, Uncertainty, R... 1884-07-01
# 456  Emotions:\n[Longing, Isolation]\n\nCharacters:... 1885-09-04
# 458  Emotions:\n[Desperation, Admiration]\n\nCharac... 1885-10-01
# 545  Emotions:\n[Frustration, Inspiration]\n\nChara... 1888-06-29
# 573  Emotions:\n[Creativity, Isolation, Determinati... 1888-09-12
# 581  Emotions:\n[Inspiration, Impatience]\n\nCharac... 1888-09-26
# 667  Emotions:\n[Determination, Gratitude, Contentm... 1889-11-21
# 670  Emotions:\n[Engrossment, Frustration, Satisfac... 1889-12-07
# 676  Emotions:\n[Gratitude, Determination, Solace, ... 1890-01-15
# 758  Emotions:\n[Passion, Nostalgia, Melancholy, In... 1883-01-20
# 771  Emotions:\n[Inspired, Hopeful]\n\nCharacters:\... 1883-05-25
# 797  Emotions:\n[Passion, Distress, Solace, Hope, D... 1888-10-23
# 823  Emotions:\n[Isolation, Happiness, Longing, Hop... 1890-01-31
# 835  Emotions:\n[Anxiety, Determination]\n\nCharact... 1890-06-30
# 840  Emotions:\n[Intensity, Solitude, Longing]\n\nC... 1888-02-28
# 841  Emotions:\n[Introspective, Struggling]\n\nChar... 1888-03-30
# 858  Emotions:\n[Anxiety, Solitude, Gratitude, Year... 1890-02-20
#
#                                               Emotions  \
# 7                               [Sorrowful, Unsettled]
# 14         [Passion, Isolation, Longing, Concern, Joy]
# 114                           [Yearning, Perseverance]
# 126                           [Desolation, Melancholy]
# 177                             [Desolation, Disquiet]
# 179                              [Isolation, Yearning]
# 191                            [Anticipation, Anxiety]
# 198     [Desolation, Introspection, Anxiety, Yearning]
# 202                           [Anxiety, Determination]
# 210               [Struggle, Passion, Longing, Relief]
# 263                            [Struggle, Hopefulness]
# 269                               [Isolation, Longing]
# 299                          [Uncertainty, Loneliness]
# 313  [Struggle, Passion, Isolation, Determination, ...
# 325  [Passionate, Restless, Hopeful, Nervous, Deter...
# 395                       [Preoccupied, Contemplative]
# 396  [Passion, Gratitude, Uncertainty, Restraint, L...
# 456                               [Longing, Isolation]
# 458                          [Desperation, Admiration]
# 545                         [Frustration, Inspiration]
# 573   [Creativity, Isolation, Determination, Yearning]
# 581                          [Inspiration, Impatience]
# 667            [Determination, Gratitude, Contentment]
# 670    [Engrossment, Frustration, Satisfaction, Worry]
# 676  [Gratitude, Determination, Solace, Contemplative]
# 758     [Passion, Nostalgia, Melancholy, Invigoration]
# 771                                [Inspired, Hopeful]
# 797   [Passion, Distress, Solace, Hope, Determination]
# 823      [Isolation, Happiness, Longing, Hope, Sorrow]
# 835                           [Anxiety, Determination]
# 840                     [Intensity, Solitude, Longing]
# 841                        [Introspective, Struggling]
# 858  [Anxiety, Solitude, Gratitude, Yearning, Intri...
#
#                                             Characters  \
# 7    [Van Gogh, Theo (mentioned), Mrs. Tersteeg (me...
# 14       [Vincent Van Gogh, Theo Van Gogh (mentioned)]
# 114  [Vincent Van Gogh, Theo(mentioned), Reverend M...
# 126  [Vincent Van Gogh, Theo Van Gogh(mentioned), B...
# 177                       [Van Gogh, Theo (mentioned)]
# 179  [Vincent van Gogh, Uncle(mentioned), Theo(ment...
# 191  [Vincent Van Gogh, Theo (mentioned), Weissenbr...
# 198                        [Van Gogh, Theo(mentioned)]
# 202  [Van Gogh, Theo(mentioned), Mauve(mentioned), ...
# 210  [Van Gogh, Theo(mentioned), Mauve(mentioned), ...
# 263  [Vincent van Gogh, Theo van Gogh(mentioned), M...
# 269  [Vincent Van Gogh, Theo Van Gogh (mentioned), ...
# 299                        [Van Gogh, Theo(mentioned)]
# 313       [Vincent Van Gogh, Theo Van Gogh(mentioned)]
# 325       [Vincent Van Gogh, Theo Van Gogh(mentioned)]
# 395  [Vincent Van Gogh, Theo(mentioned), Fromentin(...
# 396  [Vincent Van Gogh, Theo (mentioned), Breitner ...
# 456  [Vincent Van Gogh, Theo(Van Gogh's brother, me...
# 458       [Vincent Van Gogh, Theo Van Gogh(mentioned)]
# 545                     [Van Gogh, Brother(mentioned)]
# 573  [Van Gogh, Theo(mentioned), Gauguin(mentioned)...
# 581  [Van Gogh, Theo(mentioned), Milliet(mentioned)...
# 667  [Vincent van Gogh, Theo van Gogh(mentioned), M...
# 670  [Vincent Van Gogh, Theo (mentioned), Jo (menti...
# 676  [Van Gogh, Theo(mentioned), Lauzet(mentioned),...
# 758  [Vincent Van Gogh, Rappard(mentioned), Boyd Ho...
# 771  [Vincent van Gogh, Rappard(mentioned), Reinhar...
# 797  [Vincent Van Gogh, Theo Van Gogh(mentioned), F...
# 823  [Vincent Van Gogh, Theo (mentioned), Jo (menti...
# 835  [Van Gogh, Theo(mentioned), Jo(mentioned), Mis...
# 840  [Van Gogh, Sister(mentioned), Mauve(mentioned)...
# 841  [Van Gogh, Sister(mentioned), Mauve(mentioned)...
# 858  [Vincent Van Gogh, Sister(mentioned), Mother(m...
#
#                                                Context Relevance  \
# 7    This scene represents when Van Gogh was about ...         8
# 14   This scene happens in Van Gogh's young adult y...         7
# 114  This scene occurs when Van Gogh is a young man...         8
# 126  This scene depicts an isolated Van Gogh in Ams...         9
# 177  This scene occurs after Van Gogh has returned ...         7
# 179  This scene depicts a period of Vincent van Gog...         8
# 191  This scene occurs in 1882, during Vincent Van ...         8
# 198  This scene happens in April 1882, highlighting...         8
# 202  This is a moment during Van Gogh's time in The...         8
# 210  This scene takes place during a period of Vinc...         9
# 263  This scene happens in late 1882 at Vincent van...         8
# 269  In this scene, Vincent Van Gogh is alone in hi...         9
# 299  During spring of 1883, Van Gogh was living in ...         8
# 313  This scene occurs during the summer of 1883, a...         9
# 325  This scene is set in the summer of 1883 when V...         9
# 395  This scene depicts a time in the dutch period ...         8
# 396  In the summer of 1884, Van Gogh lived in Nuene...         9
# 456  This scene is set in Nuenen, Netherlands in 18...         9
# 458  This scene happens in Vincent Van Gogh's young...         8
# 545  This scene provides insight into Van Gogh's li...         9
# 573  This scene portrays a time in Van Gogh's life ...         9
# 581  Vincent is in his studio in Arles in Autumn 18...         8
# 667  In the heart of the winter of 1889, Vincent Va...         9
# 670  The scene depicts December 1889 in Saint-Rémy,...         9
# 676  This scene occurs in the winter of 1890, durin...         8
# 758  This scene happens during Van Gogh's stay at T...         8
# 771  This scene is taking place in 1883 in Van Gogh...         8
# 797  This scene takes place in 1888 Paris, illustra...         9
# 823  This scene takes place in 1890, during a time ...         9
# 835  This scene likely takes place in the late 1880...         8
# 840  This scene unfolds during Van Gogh's voluntary...         8
# 841  This scene describes a period in Van Gogh's li...         9
# 858  This scene takes place in February 1890, when ...         9
#
#                                              Paintings  \
# 7                                               [None]
# 14                                              [None]
# 114  ['The Church at Auvers', 'View of the Sea at S...
# 126                                             [None]
# 177                   ["At Eternity's Gate", "Sorrow"]
# 179                      [None specifically mentioned]
# 191                  [No specific paintings mentioned]
# 198                     [No specific painting related]
# 202  ['The Vegetable Gardens along the Laan van Mee...
# 210                            ["Sorrow", "The Roots"]
# 263  [Les Buveurs d’Eau(mentioned), Old Man's Litho...
# 269                                             [None]
# 299                                      ['The Dunes']
# 313                            [None directly related]
# 325       [No specific paintings related to the scene]
# 395                   ["The Spinner", "The Large Man"]
# 396  [Woman Spinning, Large Study, Two Studies of W...
# 456                        ["Still Life: Bird's Nest"]
# 458       ['Still Lifes', 'Two Sketches of Amsterdam']
# 545                           ["Sunset at Montmajour"]
# 573           ["The Yellow House", "Van Gogh's Chair"]
# 581  ["Ploughed Field under a Stormy Sky", "Portrai...
# 667                         [Olive Trees, Wheat Field]
# 670  ['Olives', 'Bedroom', 'Reaper', 'Wheat Field w...
# 676  ["The Starry Night", "The Wheat Field Behind S...
# 758               [No related paintings in this scene]
# 771  ["Peat Cutters in the Dunes", "Washed Ashore(m...
# 797                                  ['Les Bretonnes']
# 823                             [None directly linked]
# 835                         ["Portrait of Dr. Gachet"]
# 840                            [None directly related]
# 841  ['Trees In Bloom', 'Souvenir de Mauve', 'Study...
# 858  ['Branches with Almond Blossoms', 'The Arlesie...
#
#                                                Comment  \
# 7    The scene under review is crucial in understan...
# 14   This scene provides a deep insight into Vincen...
# 114  This pre-artistry phase of Van Gogh's life sig...
# 126  This scene is profound in its depiction of Van...
# 177  This scene reveals a key period in Van Gogh's ...
# 179  This scene showcases a heartfelt plea by Van G...
# 191  The scene beautifully articulates Van Gogh's i...
# 198  The scene captures a pivotal moment in Van Gog...
# 202  This particular scene paints a vivid picture o...
# 210  In this emotionally charged scene, we are offe...
# 263  This scene offers immense insight into Vincent...
# 269  This scene provides an intimate glimpse into V...
# 299  In this scene, we encounter an introspective V...
# 313  The letter that Van Gogh wrote to his brother ...
# 325  In this scene, we get a vivid account of Van G...
# 395  This scene offers valuable insights into Van G...
# 396  The scene grants insight into one of the most ...
# 456  Van Gogh frequently confronted feelings of iso...
# 458  In this revealing and emotionally charged scen...
# 545  In reviewing this scene, we see the paradox of...
# 573  This period of Van Gogh's life was significant...
# 581  This scene is a profound look into Van Gogh's ...
# 667  This scene captures a critical period in Van G...
# 670  This pivotal scene conveys the emotional turbu...
# 676  This scene vividly illustrates Vincent's menta...
# 758  This scene provides meaningful insight into Va...
# 771  This scene portrays a creatively stimulated Va...
# 797  This scene encapsulates a crucial period in Va...
# 823  This scene encapsulates the intricate relation...
# 835  This scene represents a critical juncture in V...
# 840  Van Gogh’s relocation to Arles, France and his...
# 841  This emotionally charged scene underscores Van...
# 858  The scene presents a thoughtful and introspect...
#
#                                        NARRATOR (V.O.)  \
# 7    In 1873, an emotional unsettled Van Gogh was t...
# 14
# 114
# 126  In November 1877, a desolate Vincent Van Gogh ...
# 177  Van Gogh, returning from Hague, is reflecting ...
# 179
# 191
# 198  We are now in The Hague, in early April 1882. ...
# 202
# 210
# 263  As we move into late 1882, within a humble Dut...
# 269
# 299
# 313
# 325
# 395  In the early June of 1884, Vincent van Gogh, a...
# 396  In the summer of 1884, Vincent Van Gogh is liv...
# 456
# 458
# 545
# 573  Van Gogh, residing in Arles in late 1888, is e...
# 581  As autumn set in 1888 in Arles, Vincent Van Go...
# 667
# 670  We are now pulled into the world of Vincent va...
# 676  In the winter of 1890, Vincent Van Gogh found ...
# 758
# 771
# 797  In the autumn of 1888, Vincent van Gogh found ...
# 823  In the winter of 1890, Vincent van Gogh, strug...
# 835
# 840  Vincent van Gogh, a passionate post-impression...
# 841  In the year 1888, a deeply introspective Vince...
# 858
#
#                                             BACKGROUND  \
# 7    May 9, 1873, a humble Dutch residence in The H...
# 14   :\nThe scene unfolds in a modest, dimly-lit ro...
# 114  It is Sunday morning. Rain falls softly on cob...
# 126  Twilight descends upon the city of Amsterdam. ...
# 177
# 179  :\nA small, modest Dutch room draped in the wa...
# 191  Cut to an exasperatingly plain yet intimately ...
# 198  .\nA small, unruly apartment is bathed in the ...
# 202  Dim light pours through a quartered window, gl...
# 210  Inside his lonely studio in The Hague, Van Gog...
# 263  The Hague's chilly wind whistles outside, the ...
# 269  A quaint artist's studio bathed in soft winter...
# 299  We are transported to a lonely room, scarcely ...
# 313  The scene is set in a humble studio in The Hag...
# 325  A small, modest room bathed in afternoon light...
# 395  :\nWe are in Van Gogh's simple, dusty interior...
# 396  We are in an austere Dutch room with solid woo...
# 456  An artist's humble abode in the rural town of ...
# 458  The frame captures a dimly lit room in Nuenen,...
# 545  Sunset over the quaint French countryside of A...
# 573  :\nA small, dimly-lit room in Arles, scattered...
# 581  An art studio catches the morning light. Canva...
# 667  As the camera sweeps through the luscious oliv...
# 670  A humble room teems with the scent of oil pain...
# 676  In the dim candle-lit interior of a room at th...
# 758  A small, cluttered room lit only by a single l...
# 771  The scene unfolds in Van Gogh’s small, humble ...
# 797  We are in dirty but lively streets of Paris, O...
# 823  A dimly lit room adorned with eclectic art, ca...
# 835  The scene unfolds in a humble Parisian flat, c...
# 840  A dismal, dimly lit room indoors; every object...
# 841  A humble room in Arles, brimming with canvases...
# 858  The rustic room at the asylum, illuminated onl...
#
#                                VINCENT VAN GOGH (V.O.)
# 7
# 14   Theo, Dear Brother, my days in London are fill...
# 114  Today, I left for service amidst rain, and whe...
# 126
# 177
# 179  Dear Uncle, Time finds me in the throes of dee...
# 191  Ah, dear Theo... your letters lend a semblance...
# 198
# 202  Theo, today I sent you another drawing, the Ve...
# 210  Dear Theo, your letter has given clarity amids...
# 263
# 269  Theo, dear brother... I wish we could share th...
# 299  Dear Theo, Life carries on, each brushstroke a...
# 313  Dear Theo, my figures show progress, and yet, ...
# 325  Dear Theo, I’m here, lost and found in my art,...
# 395
# 396
# 456  "Dear Theo, the sense of isolation wraps aroun...
# 458
# 545  My dear brother, I find myself engrossed with ...
# 573
# 581
# 667  My dear brother Theo, your gift of paints and ...
# 670
# 676
# 758  Amice Rappard, I have lost myself in these Gra...
# 771  Amice Rappard, I feel the vigor of creative li...
# 797
# 823
# 835  "My dearest brother, our dear little boy has b...
# 840
# 841
# 858  My Dear Sister, \n\nIt appears as though ordin...

# %%
sub_dataset.index
# Out:
# Int64Index([  7,  14, 114, 126, 177, 179, 191, 198, 202, 210, 263, 269, 299,
#             313, 325, 395, 396, 456, 458, 545, 573, 581, 667, 670, 676, 758,
#             771, 797, 823, 835, 840, 841, 858],
#            dtype='int64')

# %%
df_expanded.loc[list(sub_dataset.index)] = sub_dataset.loc[list(sub_dataset.index)]

# %%
narrator_empty_count = (df_expanded['NARRATOR (V.O.)'] == "").sum()
background_empty_count = (df_expanded['BACKGROUND'] == "").sum()
vincent_empty_count = (df_expanded['VINCENT VAN GOGH (V.O.)'] == "").sum()

print("Empty 'NARRATOR (V.O.)' count:", narrator_empty_count)
print("Empty 'BACKGROUND' count:", background_empty_count)
print("Empty 'VINCENT VAN GOGH (V.O.)' count:", vincent_empty_count)
# Out:
# Empty 'NARRATOR (V.O.)' count: 18
# Empty 'BACKGROUND' count: 1
# Empty 'VINCENT VAN GOGH (V.O.)' count: 16

# %%
df_expanded
# Out:
#            file_name        date origin sender             receiver  \
# 0    001_V-T_001.pdf  1872-08-01    T-H    VvG                  TvG
# 1    002_V-T_002.pdf  1872-12-13    T-H    VvG                  TvG
# 2    003_V-T_003.pdf  1873-01-01    T-H    VvG                  TvG
# 3    004_V-T_004.pdf  1873-01-28    T-H    VvG                  TvG
# 4    005_V-T_005.pdf  1873-03-17    T-H    VvG                  TvG
# ..               ...         ...    ...    ...                  ...
# 857  802_V-W_W19.pdf  1890-01-20    S-R    VvG  Wilhelmina van Gogh
# 858  813_V-W_W20.pdf  1890-02-20    S-R    VvG  Wilhelmina van Gogh
# 859  831_V-W_W21.pdf  1890-05-20    S-R    VvG  Wilhelmina van Gogh
# 860  839_V-W_W22.pdf  1890-06-05  A-s-O    VvG  Wilhelmina van Gogh
# 861  844_V-W_W23.pdf  1890-06-12  A-s-O    VvG  Wilhelmina van Gogh
#
#                                                content  \
# 0    Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1    Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2    Letter 003\nThe Hague, January 1873\nMy dear T...
# 3    Letter 004\nThe Hague, January 28 1873\nDear T...
# 4    Letter 005\nThe Hague, 17 March 1873\nDear The...
# ..                                                 ...
# 857  W19 1\nSaint-Rémy, 20 January 1890\nDear Siste...
# 858  W20 1\nSaint-Rémy, c. 20 February 1890\nMy Dea...
# 859  W21 1\nAuvers, c. 20 May 1890\nMy Dear Sister,...
# 860  W22 1\nAuvers-sur-Oise, 5 June 1890\nMy Dear S...
# 861  Letter W23 1\nAuvers-sur-Oise, c. 12 June 1890...
#
#                                           API_Response  \
# 0    NARRATOR (V.O.)\nIn the period post the depart...
# 1    NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2    NARRATOR (V.O.)\nWe find ourselves in the year...
# 3    NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4    NARRATOR (V.O.)\nWe are venturing into the lif...
# ..                                                 ...
# 857  NARRATOR (V.O.)\nIn this scene, we examine a t...
# 858  NARRATOR (V.O)\nIn February 1890, post-impress...
# 859  NARRATOR (V.O.)\nWe find ourselves in the late...
# 860  NARRATOR (V.O.)\nWe are in the summer of 1890,...
# 861  NARRATOR (V.O.)\nJune 1890. Van Gogh is in Auv...
#
#                                         Scene_Analysis  timestamp  \
# 0    Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1    Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2    Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3    Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4    Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
# ..                                                 ...        ...
# 857  Emotions:\n[Anxiety, Longing, Restlessness, So... 1890-01-20
# 858  Emotions:\n[Anxiety, Solitude, Gratitude, Year... 1890-02-20
# 859  Emotions:\n[Gratitude, Contentment]\n\nCharact... 1890-05-20
# 860  Emotions:\n[Determination, Longing]\n\nCharact... 1890-06-05
# 861  Emotions:\n[Desperation, Burdened, Longing, Ur... 1890-06-12
#
#                                               Emotions  \
# 0                              [Melancholy, Nostalgia]
# 1                                     [Joy, Eagerness]
# 2    [Loneliness, Comfort, Joy, Ambition, Anticipat...
# 3                                      [Longing, Pity]
# 4                            [Anticipation, Nostalgia]
# ..                                                 ...
# 857           [Anxiety, Longing, Restlessness, Solace]
# 858  [Anxiety, Solitude, Gratitude, Yearning, Intri...
# 859                           [Gratitude, Contentment]
# 860                           [Determination, Longing]
# 861          [Desperation, Burdened, Longing, Urgency]
#
#                                             Characters  \
# 0    [Vincent Van Gogh, Theo Van Gogh(mentioned), H...
# 1    [Vincent Van Gogh, Theo Van Gogh(mentioned), R...
# 2    [Vincent Van Gogh, Theo Van Gogh(mentioned), S...
# 3    [Vincent van Gogh, Theo van Gogh(mentioned), U...
# 4    [Vincent van Gogh, Theo van Gogh(mentioned), U...
# ..                                                 ...
# 857  [Van Gogh, Sister(mentioned), Gauguin(mentione...
# 858  [Vincent Van Gogh, Sister(mentioned), Mother(m...
# 859  [Van Gogh, Sister(mentioned), Theo(mentioned),...
# 860  [Vincent Van Gogh, Dr. Gachet, Theo Van Gogh(m...
# 861  [Van Gogh, Theo(mentioned), Sister(mentioned),...
#
#                                                Context Relevance  \
# 0    This scene is set in the winter of 1872 in Van...         8
# 1    This scene reflects a young Vincent van Gogh's...         7
# 2    This scene depicts the young Van Gogh in 1873,...         8
# 3    This scene describes a time when Van Gogh was ...         7
# 4    The scene takes place in the spring of 1873, a...         8
# ..                                                 ...       ...
# 857  This scene captures a period of Van Gogh's lif...         8
# 858  This scene takes place in February 1890, when ...         9
# 859  This scene takes place after Van Gogh left the...         9
# 860  This scene is from the summer of 1890, shortly...         8
# 861  This scene takes place in June 1890 when Van G...        10
#
#                                              Paintings  \
# 0                         (None provided in the scene)
# 1                                               [None]
# 2                                               [None]
# 3    [None specific, but might be loosely related t...
# 4                                                 None
# ..                                                 ...
# 857                     ['Women in the Olive Orchard']
# 858  ['Branches with Almond Blossoms', 'The Arlesie...
# 859                   [Roses, Violets, Olive Orchards]
# 860  ["Dr. Gachet's Portrait", "The Church at Auvers"]
# 861  ["Dr. Gachet", "Landscape with poplars", "Pota...
#
#                                                Comment  \
# 0    This poignant scene underscores the emotional ...
# 1    This scene is rather significant in understand...
# 2    This scene is both captivating and enlightenin...
# 3    This revealing scene captures a thoughtful and...
# 4    This is a significant moment in van Gogh's lif...
# ..                                                 ...
# 857  In this scene, we see Van Gogh wrestling with ...
# 858  The scene presents a thoughtful and introspect...
# 859  This scene is quite significant and encapsulat...
# 860  The scene under examination showcases the intr...
# 861  The scene is strategically set in June 1890, o...
#
#                                        NARRATOR (V.O.)  \
# 0    In the period post the departure of his brothe...
# 1    In 1872, Vincent van Gogh, known for his vivid...
# 2    We find ourselves in the year 1873, in the pat...
# 3    In the winter of 1873, a young Vincent van Gog...
# 4    We are venturing into the life and mind of Vin...
# ..                                                 ...
# 857  In this scene, we examine a time in Vincent va...
# 858
# 859  We find ourselves in the late spring of 1890. ...
# 860  We are in the summer of 1890, Vincent Van Gogh...
# 861  June 1890. Van Gogh is in Auvers-sur-Oise, liv...
#
#                                             BACKGROUND  \
# 0    As the winter rain dwarfs against the aged gla...
# 1    :\nThis scene takes place in a dimly lit room ...
# 2    :\nThe intimate sanctuary of Van Gogh's small ...
# 3    Late January evening fills the room in a board...
# 4    :\nThe scene unfolds in the cozy, dimly lit ro...
# ..                                                 ...
# 857  :\nThis scene is set in the quintessentially l...
# 858  The rustic room at the asylum, illuminated onl...
# 859  The scene starts in a modest room, bathed in t...
# 860  A small room bathed in the warm hues of the ev...
# 861  A dimly lit room. Shafts of pale morning light...
#
#                                VINCENT VAN GOGH (V.O.)
# 0    Dearest Theo, your absence in the homestead ha...
# 1    Dear Theo, Words could hardly express my joy i...
# 2    My dear Theo... I found comfort in hearing you...
# 3    Dear Theo, \nI find solace in your letter and ...
# 4    Dear Theo, I long to hear of you and Uncle Hei...
# ..                                                 ...
# 857  Dear Sister, \nThe Paris I was once entranced ...
# 858  My Dear Sister, \n\nIt appears as though ordin...
# 859  My dear Sister,\nThrongs of unuttered thoughts...
# 860  June 5th, 1890...Auvers-sur-Oise. My dearest s...
# 861  My dear sister, the desperately swift passing ...
#
# [862 rows x 18 columns]

# %% [markdown]
# # 2. Emotion to Valence and Arousal

# %%
# prompt: Using dataframe df_expanded: iterate over the emotions column, which contains lists, and append them to a single list, then get a set of the list

emotions_list = []
for i in range(len(df_expanded)):
    emotions = df_expanded.loc[i, 'Emotions'].strip('[]').split(',')
    for emotion in emotions:
        emotions_list.append(emotion.strip().strip('\'').lower())

emotions_set = set(emotions_list)

print(emotions_set)
# Out:
# {'turbulence', 'misunderstood', 'accomplishment', 'nervous', 'discouragement', 'insecurity', 'focus', 'solidarity', 'conviction', 'passionate', 'compulsion', 'appreciation', 'enthusiasm', 'regretful', 'displacement', 'struggling', 'distressed', 'guilt', 'contemplation', 'dissatisfaction', 'impotence', 'anxiety', 'inquisitiveness', 'solitary', 'conflicted', 'maddening', 'awestruck', 'obsession', 'unease', 'captivation', 'vibrancy', 'lonely', 'gloom', 'stress', 'rage', 'pity', 'compassion', 'contentment', 'pained', 'discerning', 'devoted', 'defiance', 'coping', 'calmness', 'enrapturement', 'striving', 'inspired', 'remote', 'mesmerized', 'eagerness', 'fear', 'infatuated', 'peace', 'relentless', 'despondent', 'exhiliration', 'grief', 'disillusionment', 'fondness', 'turmoil', 'endeavor', 'nervousness', 'compassionate', 'eager', 'solace', 'repugnance', 'agony', 'determination', 'dread', 'hurt', 'defiant', 'melancholy', 'burdened', 'gratefulness', 'heartbreak', 'startled', 'troubled', 'driven', 'tranquility', 'agitation', 'boredom', 'perturbation', 'thankful', 'comforted', 'frustrated', 'awe', 'pensiveness', 'yearning', 'intrigue', 'sorrowful', 'aspiration', 'thrill', 'entranced', 'tiredness', 'helplessness', 'fatigue', 'connectedness', 'preoccupation', 'belief', 'doubt', 'trepidation', 'strength', 'sadness', 'estranged', 'courage', 'loss', 'resignation', 'regret', 'struggled', 'worn', 'reflective', 'optimism', 'nostalgia', 'faithfulness', 'disconcertment', 'encouragement', 'happy', 'relieved', 'desiring', 'companionship', 'gratified', 'isolation', 'excitement', 'despondency', 'concern', 'mania', 'zeal', 'absent-mindedness', 'diligence', 'isolated', 'distress', 'weary', 'invigorated', 'joy', 'melancholia', 'lucidity', 'restraint', 'productivity', 'pain', 'mourning', 'resolution', 'introspective', 'renewal', 'conflict', 'urgency', 'wistfulness', 'fascination', 'strained', 'remorse', 'solemn', 'perplexed', 'stubbornness', 'overwhelmed', 'alarmed', 'unrest', 'resilient', 'despair', 'longing', 'ecstasy', 'daunted', 'delight', 'consumed', 'inspiration', 'intensity', 'validated', 'determined', 'invigoration', 'stationary', 'wistfultness', 'introspection', 'responsibility', 'astonishment', 'spirituality', 'disappointment', 'nostalgic', 'anticipation', 'liberated', 'ambition', 'resentment', 'suffering', 'fury', 'restlessness', 'torn', 'dedication', 'injustice', 'patience', 'revelation', 'sorrow', 'sincerity', 'confusion', 'pressure', 'pride', 'hopeful', 'discomfort', 'passion', 'desolation', 'weariness', 'disheartenment', 'desperation', 'apprehension', 'enchantment', 'committed', 'trapped', 'congratulatory', 'weakness', 'melancholic', 'connection', 'disappointed', 'turbulent', 'drive', 'hope', 'frantic', 'exhilaration', 'grateful', 'excited', 'disillusioned', 'absorbed', 'ache', 'sensitivity', 'rejuvenation', 'disquiet', 'freedom', 'resolute', 'engrossed', 'pensive', 'strife', 'self-doubt', 'morose', 'bitterness', 'peaceful', 'anger', 'strive', 'vigor', 'exasperation', 'indignation', 'absorption', 'hopefulness', 'love', 'resolve', 'paralysis', 'overwhelming', 'care', 'saddened', 'vibrant', 'restless', 'frustration', 'fulfillment', 'insightful', 'depression', 'torment', 'wistful', 'complexity', 'optimistic', 'surprise', 'warmth', 'engrossment', 'epiphany', 'jubilance', 'cheerful', 'devotion', 'humor', 'acceptance', 'tension', 'solitude', 'resentful', 'seriousness', 'empathy', 'resoluteness', 'relief', 'elation', 'anguish', 'misery', 'chaos', 'alienation', 'anxious', 'exhaustion', 'faith', 'creativity', 'emotional', 'respect', 'zealous', 'hunger', 'enrichment', 'serenity', 'persistence', 'affected', 'contemplative', 'anarchy', 'perseverance', 'revival', 'discontentment', 'relentlessness', 'impatience', 'resilience', 'peacefulness', 'serene', 'concerned', 'gratitude', 'adventure', 'reflection', 'admiring', 'hopelessness', 'existential-anguish', 'overwhelm', 'perplexity', 'admiration', 'unsettled', 'bewitched', 'intimate', 'anxiousness', 'comfor ...

# %%
print(len(emotions_list))
print(len(emotions_set))
# Out:
# 2735
# 341

# %%
df_va = pd.read_csv("/content/drive/MyDrive/SFU/STeve/DocsToExtractData/letters_words_valence_arousal.csv", index_col=0)
df_va.head()
# Out:
#            Word            Valence_Arousal
# 0      absorbed         absorbed:[0.5,0.2]
# 1  wistfultness  wistfulness: [-0.2, -0.1]
# 2     adventure        adventure:[0.7,0.8]
# 3    turbulence      turbulence:[-0.7,0.8]
# 4    impatience      impatience:[-0.7,0.6]

# %%
"confused:[-0.6,0.4]".split(":")[1].strip().strip("[").strip("]").split(",")
# Out:
# ['-0.6', '0.4']

# %%
df_va[['Valence', 'Arousal']] = df_va['Valence_Arousal'].str.split(':').str[1].str.strip().str.strip("'").str.strip('[]').str.split(',', expand=True)
df_va.head()
# Out:
#            Word            Valence_Arousal Valence Arousal
# 0      absorbed         absorbed:[0.5,0.2]     0.5     0.2
# 1  wistfultness  wistfulness: [-0.2, -0.1]    -0.2    -0.1
# 2     adventure        adventure:[0.7,0.8]     0.7     0.8
# 3    turbulence      turbulence:[-0.7,0.8]    -0.7     0.8
# 4    impatience      impatience:[-0.7,0.6]    -0.7     0.6

# %%
df_va['Valence'] = pd.to_numeric(df_va['Valence'])
df_va['Arousal'] = pd.to_numeric(df_va['Arousal'])

# %%
df_va = df_va.drop("Valence_Arousal", axis=1)

# %%
df_va = df_va.set_index(df_va.columns[0])

# %%
df_va.head()
# Out:
#               Valence  Arousal
# Word
# absorbed          0.5      0.2
# wistfultness     -0.2     -0.1
# adventure         0.7      0.8
# turbulence       -0.7      0.8
# impatience       -0.7      0.6

# %%
import numpy as np

lista = np.array(["Desperation", "Isolation", "Passion"])

def get_average_VA(emotions):
    if not emotions:
        return np.array([0,0])

    lista = np.array(emotions)
    formatted_lista = [word.lower().strip() for word in lista if word.strip()]

    if not formatted_lista:
        return np.array([0,0])

    try:
        sums = df_va.loc[formatted_lista].to_numpy().sum(axis=0)
        result = sums / len(formatted_lista)
        return result
    except KeyError as e:
        print(f"KeyError: {e}")
        return np.array([0,0])

# %%
df_expanded.columns
# Out:
# Index(['file_name', 'date', 'origin', 'sender', 'receiver', 'content',
#        'API_Response', 'Scene_Analysis', 'timestamp', 'Emotions', 'Characters',
#        'Context', 'Relevance', 'Paintings', 'Comment', 'NARRATOR (V.O.)',
#        'BACKGROUND', 'VINCENT VAN GOGH (V.O.)'],
#       dtype='object')

# %%
df_expanded["Emotions"].iloc[0].strip("[").strip("]").split(",")
# Out:
# ['Melancholy', ' Nostalgia']

# %%
emotions_list = df_expanded["Emotions"].str.strip("[").str.strip("]").str.split(",")
emotions_clean = emotions_list.apply(lambda x: [word.strip() for word in x if word.strip()])
emotions_clean
# Out:
# 0                                [Melancholy, Nostalgia]
# 1                                       [Joy, Eagerness]
# 2      [Loneliness, Comfort, Joy, Ambition, Anticipat...
# 3                                        [Longing, Pity]
# 4                              [Anticipation, Nostalgia]
#                              ...
# 857             [Anxiety, Longing, Restlessness, Solace]
# 858    [Anxiety, Solitude, Gratitude, Yearning, Intri...
# 859                             [Gratitude, Contentment]
# 860                             [Determination, Longing]
# 861            [Desperation, Burdened, Longing, Urgency]
# Name: Emotions, Length: 862, dtype: object

# %%
va_values = emotions_clean.apply(get_average_VA)

# Split the returned lists into two separate columns
df_expanded['Valence'], df_expanded['Arousal'] = zip(*va_values)

df_expanded.head()
# Out:
# KeyError: "None of [Index([''isolation'', ''yearning'', ''sadness'', ''hope''], dtype='object', name='Word')] are in the [index]"
#          file_name        date origin sender receiver  \
# 0  001_V-T_001.pdf  1872-08-01    T-H    VvG      TvG
# 1  002_V-T_002.pdf  1872-12-13    T-H    VvG      TvG
# 2  003_V-T_003.pdf  1873-01-01    T-H    VvG      TvG
# 3  004_V-T_004.pdf  1873-01-28    T-H    VvG      TvG
# 4  005_V-T_005.pdf  1873-03-17    T-H    VvG      TvG
#
#                                              content  \
# 0  Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1  Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2  Letter 003\nThe Hague, January 1873\nMy dear T...
# 3  Letter 004\nThe Hague, January 28 1873\nDear T...
# 4  Letter 005\nThe Hague, 17 March 1873\nDear The...
#
#                                         API_Response  \
# 0  NARRATOR (V.O.)\nIn the period post the depart...
# 1  NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2  NARRATOR (V.O.)\nWe find ourselves in the year...
# 3  NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4  NARRATOR (V.O.)\nWe are venturing into the lif...
#
#                                       Scene_Analysis  timestamp  \
# 0  Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1  Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2  Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3  Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4  Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
#
#                                             Emotions  \
# 0                            [Melancholy, Nostalgia]
# 1                                   [Joy, Eagerness]
# 2  [Loneliness, Comfort, Joy, Ambition, Anticipat...
# 3                                    [Longing, Pity]
# 4                          [Anticipation, Nostalgia]
#
#                                           Characters  \
# 0  [Vincent Van Gogh, Theo Van Gogh(mentioned), H...
# 1  [Vincent Van Gogh, Theo Van Gogh(mentioned), R...
# 2  [Vincent Van Gogh, Theo Van Gogh(mentioned), S...
# 3  [Vincent van Gogh, Theo van Gogh(mentioned), U...
# 4  [Vincent van Gogh, Theo van Gogh(mentioned), U...
#
#                                              Context Relevance  \
# 0  This scene is set in the winter of 1872 in Van...         8
# 1  This scene reflects a young Vincent van Gogh's...         7
# 2  This scene depicts the young Van Gogh in 1873,...         8
# 3  This scene describes a time when Van Gogh was ...         7
# 4  The scene takes place in the spring of 1873, a...         8
#
#                                            Paintings  \
# 0                       (None provided in the scene)
# 1                                             [None]
# 2                                             [None]
# 3  [None specific, but might be loosely related t...
# 4                                               None
#
#                                              Comment  \
# 0  This poignant scene underscores the emotional ...
# 1  This scene is rather significant in understand...
# 2  This scene is both captivating and enlightenin...
# 3  This revealing scene captures a thoughtful and...
# 4  This is a significant moment in van Gogh's lif...
#
#                                      NARRATOR (V.O.)  \
# 0  In the period post the departure of his brothe...
# 1  In 1872, Vincent van Gogh, known for his vivid...
# 2  We find ourselves in the year 1873, in the pat...
# 3  In the winter of 1873, a young Vincent van Gog...
# 4  We are venturing into the life and mind of Vin...
#
#                                           BACKGROUND  \
# 0  As the winter rain dwarfs against the aged gla...
# 1  :\nThis scene takes place in a dimly lit room ...
# 2  :\nThe intimate sanctuary of Van Gogh's small ...
# 3  Late January evening fills the room in a board...
# 4  :\nThe scene unfolds in the cozy, dimly lit ro...
#
#                              VINCENT VAN GOGH (V.O.)  Valence  Arousal
# 0  Dearest Theo, your absence in the homestead ha...    -0.10    -0.30
# 1  Dear Theo, Words could hardly express my joy i...     0.90     0.70
# 2  My dear Theo... I found comfort in hearing you...     0.42     0.40
# 3  Dear Theo, \nI find solace in your letter and ...    -0.40     0.40
# 4  Dear Theo, I long to hear of you and Uncle Hei...     0.55     0.15

# %%
df_expanded[df_expanded["Relevance"] == ""]
# Out:
# Empty DataFrame
# Columns: [file_name, date, origin, sender, receiver, content, API_Response, Scene_Analysis, timestamp, Emotions, Characters, Context, Relevance, Paintings, Comment, NARRATOR (V.O.), BACKGROUND, VINCENT VAN GOGH (V.O.), Valence, Arousal]
# Index: []

# %%
df_expanded["Relevance"] = df_expanded['Relevance'].str.extract('(\d+)').astype(float)

# %%
df_expanded["Relevance"] = df_expanded["Relevance"]/10

# %%
df_expanded["Relevance"].unique()
# Out:
# array([0.8, 0.7, 0.9, 1. ])

# %%
df_expanded.head(6)
# Out:
#          file_name        date origin sender receiver  \
# 0  001_V-T_001.pdf  1872-08-01    T-H    VvG      TvG
# 1  002_V-T_002.pdf  1872-12-13    T-H    VvG      TvG
# 2  003_V-T_003.pdf  1873-01-01    T-H    VvG      TvG
# 3  004_V-T_004.pdf  1873-01-28    T-H    VvG      TvG
# 4  005_V-T_005.pdf  1873-03-17    T-H    VvG      TvG
# 5  006_V-T_006.pdf  1873-03-24    T-H    VvG      TvG
#
#                                              content  \
# 0  Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1  Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2  Letter 003\nThe Hague, January 1873\nMy dear T...
# 3  Letter 004\nThe Hague, January 28 1873\nDear T...
# 4  Letter 005\nThe Hague, 17 March 1873\nDear The...
# 5  Letter 006\nThe Hague, 24th March 1875\nDear T...
#
#                                         API_Response  \
# 0  NARRATOR (V.O.)\nIn the period post the depart...
# 1  NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2  NARRATOR (V.O.)\nWe find ourselves in the year...
# 3  NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4  NARRATOR (V.O.)\nWe are venturing into the lif...
# 5  NARRATOR (V.O.)\nWe find Van Gogh at the start...
#
#                                       Scene_Analysis  timestamp  \
# 0  Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1  Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2  Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3  Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4  Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
# 5  Emotions:\n[Anxiety, Hopefulness]\n\nCharacter... 1873-03-24
#
#                                             Emotions  \
# 0                            [Melancholy, Nostalgia]
# 1                                   [Joy, Eagerness]
# 2  [Loneliness, Comfort, Joy, Ambition, Anticipat...
# 3                                    [Longing, Pity]
# 4                          [Anticipation, Nostalgia]
# 5                             [Anxiety, Hopefulness]
#
#                                           Characters  \
# 0  [Vincent Van Gogh, Theo Van Gogh(mentioned), H...
# 1  [Vincent Van Gogh, Theo Van Gogh(mentioned), R...
# 2  [Vincent Van Gogh, Theo Van Gogh(mentioned), S...
# 3  [Vincent van Gogh, Theo van Gogh(mentioned), U...
# 4  [Vincent van Gogh, Theo van Gogh(mentioned), U...
# 5  [Van Gogh, Theo(Van Gogh's Brother), Mr. Schmi...
#
#                                              Context  Relevance  \
# 0  This scene is set in the winter of 1872 in Van...        0.8
# 1  This scene reflects a young Vincent van Gogh's...        0.7
# 2  This scene depicts the young Van Gogh in 1873,...        0.8
# 3  This scene describes a time when Van Gogh was ...        0.7
# 4  The scene takes place in the spring of 1873, a...        0.8
# 5  The scene takes place in 1875 at the start of ...        0.8
#
#                                            Paintings  \
# 0                       (None provided in the scene)
# 1                                             [None]
# 2                                             [None]
# 3  [None specific, but might be loosely related t...
# 4                                               None
# 5         [The Schotel painting(incomplete version)]
#
#                                              Comment  \
# 0  This poignant scene underscores the emotional ...
# 1  This scene is rather significant in understand...
# 2  This scene is both captivating and enlightenin...
# 3  This revealing scene captures a thoughtful and...
# 4  This is a significant moment in van Gogh's lif...
# 5  In this scene Van Gogh exhibits the earnest, p...
#
#                                      NARRATOR (V.O.)  \
# 0  In the period post the departure of his brothe...
# 1  In 1872, Vincent van Gogh, known for his vivid...
# 2  We find ourselves in the year 1873, in the pat...
# 3  In the winter of 1873, a young Vincent van Gog...
# 4  We are venturing into the life and mind of Vin...
# 5  We find Van Gogh at the start of his artistic ...
#
#                                           BACKGROUND  \
# 0  As the winter rain dwarfs against the aged gla...
# 1  :\nThis scene takes place in a dimly lit room ...
# 2  :\nThe intimate sanctuary of Van Gogh's small ...
# 3  Late January evening fills the room in a board...
# 4  :\nThe scene unfolds in the cozy, dimly lit ro...
# 5  :\nThe scene unfolds within the modest, candle...
#
#                              VINCENT VAN GOGH (V.O.)  Valence  Arousal
# 0  Dearest Theo, your absence in the homestead ha...    -0.10    -0.30
# 1  Dear Theo, Words could hardly express my joy i...     0.90     0.70
# 2  My dear Theo... I found comfort in hearing you...     0.42     0.40
# 3  Dear Theo, \nI find solace in your letter and ...    -0.40     0.40
# 4  Dear Theo, I long to hear of you and Uncle Hei...     0.55     0.15
# 5  "Dear Theo, I am impelled to correspond with y...    -0.05     0.60

# %% [markdown]
# #3. Location Extractor

# %%
di = {
"T-H":"The Hague, Netherlands",
"Nu":"Nuenen, Netherlands",
"Ar":"Arles, France",
"S-R":"Saint-Rémy, France",
"A-s-O":"Auvers-sur-Oise, France"}

# %%
df = df_expanded

# %%
df['location'] = df_expanded['origin'].apply(lambda x: di.get(x, x))

# %%
df.head(10)
# Out:
#           file_name        date  origin sender  \
# 0   001_V-T_001.pdf  1872-08-01     T-H    VvG
# 1   002_V-T_002.pdf  1872-12-13     T-H    VvG
# 2   003_V-T_003.pdf  1873-01-01     T-H    VvG
# 3   004_V-T_004.pdf  1873-01-28     T-H    VvG
# 4   005_V-T_005.pdf  1873-03-17     T-H    VvG
# 5   006_V-T_006.pdf  1873-03-24     T-H    VvG
# 6   007_V-T_007.pdf  1873-05-05     T-H    VvG
# 7   008_V-T_008.pdf  1873-05-09     T-H    VvG
# 8   009_V-T_009.pdf  1873-06-13  London    VvG
# 9  010_V-H_009a.pdf  1873-06-13  London    VvG
#
#                            receiver  \
# 0                               TvG
# 1                               TvG
# 2                               TvG
# 3                               TvG
# 4                               TvG
# 5                               TvG
# 6                               TvG
# 7                               TvG
# 8                               TvG
# 9  The Van Stockum-Haanebeek family
#
#                                              content  \
# 0  Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1  Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2  Letter 003\nThe Hague, January 1873\nMy dear T...
# 3  Letter 004\nThe Hague, January 28 1873\nDear T...
# 4  Letter 005\nThe Hague, 17 March 1873\nDear The...
# 5  Letter 006\nThe Hague, 24th March 1875\nDear T...
# 6  Letter 007\nThe Hague, 5 May 1873\nDear Theo,\...
# 7  Letter 008\nThe Hague, 9th May 1873\nDear Theo...
# 8  Letter 009\nLondon, 13 June 1873\nDear Theo,\n...
# 9  Letter 009a\nLondon, 2 July 1873\n[Letter to T...
#
#                                         API_Response  \
# 0  NARRATOR (V.O.)\nIn the period post the depart...
# 1  NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2  NARRATOR (V.O.)\nWe find ourselves in the year...
# 3  NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4  NARRATOR (V.O.)\nWe are venturing into the lif...
# 5  NARRATOR (V.O.)\nWe find Van Gogh at the start...
# 6  NARRATOR (V.O.)\nWe're deep in the moment of V...
# 7  NARRATOR (V.O.)\nIn 1873, an emotional unsettl...
# 8  NARRATOR (V.O.)\nThe time is June 13, 1873. Vi...
# 9  NARRATOR (V.O.)\nIn the summer of 1873, Vincen...
#
#                                       Scene_Analysis  timestamp  \
# 0  Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1  Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2  Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3  Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4  Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
# 5  Emotions:\n[Anxiety, Hopefulness]\n\nCharacter... 1873-03-24
# 6  Emotions:\n[Anxiety, Hope, Guilt, Nostalgia]\n... 1873-05-05
# 7  Emotions:\n[Sorrowful, Unsettled]\n\nCharacter... 1873-05-09
# 8  Emotions:\n[Loneliness, Contentment]\n\nCharac... 1873-06-13
# 9  Emotions:\n[Overwhelmed, Longing]\n\nCharacter... 1873-06-13
#
#                                             Emotions  ...  \
# 0                            [Melancholy, Nostalgia]  ...
# 1                                   [Joy, Eagerness]  ...
# 2  [Loneliness, Comfort, Joy, Ambition, Anticipat...  ...
# 3                                    [Longing, Pity]  ...
# 4                          [Anticipation, Nostalgia]  ...
# 5                             [Anxiety, Hopefulness]  ...
# 6                  [Anxiety, Hope, Guilt, Nostalgia]  ...
# 7                             [Sorrowful, Unsettled]  ...
# 8                          [Loneliness, Contentment]  ...
# 9                             [Overwhelmed, Longing]  ...
#
#                                              Context Relevance  \
# 0  This scene is set in the winter of 1872 in Van...       0.8
# 1  This scene reflects a young Vincent van Gogh's...       0.7
# 2  This scene depicts the young Van Gogh in 1873,...       0.8
# 3  This scene describes a time when Van Gogh was ...       0.7
# 4  The scene takes place in the spring of 1873, a...       0.8
# 5  The scene takes place in 1875 at the start of ...       0.8
# 6  This scene takes place in May 1873, a pivotal ...       0.8
# 7  This scene represents when Van Gogh was about ...       0.8
# 8  This scene takes place in 1873 when Van Gogh w...       0.8
# 9  This scene is set in Van Gogh's early adulthoo...       0.7
#
#                                            Paintings  \
# 0                       (None provided in the scene)
# 1                                             [None]
# 2                                             [None]
# 3  [None specific, but might be loosely related t...
# 4                                               None
# 5         [The Schotel painting(incomplete version)]
# 6                                              [N/A]
# 7                                             [None]
# 8                                             [None]
# 9  [Vincent's Bedroom in Arles, The Pink Peach Tr...
#
#                                              Comment  \
# 0  This poignant scene underscores the emotional ...
# 1  This scene is rather significant in understand...
# 2  This scene is both captivating and enlightenin...
# 3  This revealing scene captures a thoughtful and...
# 4  This is a significant moment in van Gogh's lif...
# 5  In this scene Van Gogh exhibits the earnest, p...
# 6  This pivotal moment encapsulates many of the t...
# 7  The scene under review is crucial in understan...
# 8  This scene is significantly rich for reflectin...
# 9  The given scene is crucial in understanding th...
#
#                                      NARRATOR (V.O.)  \
# 0  In the period post the departure of his brothe...
# 1  In 1872, Vincent van Gogh, known for his vivid...
# 2  We find ourselves in the year 1873, in the pat...
# 3  In the winter of 1873, a young Vincent van Gog...
# 4  We are venturing into the life and mind of Vin...
# 5  We find Van Gogh at the start of his artistic ...
# 6  We're deep in the moment of Van Gogh's life, M...
# 7  In 1873, an emotional unsettled Van Gogh was t...
# 8  The time is June 13, 1873. Vincent Van Gogh is...
# 9  In the summer of 1873, Vincent Van Gogh finds ...
#
#                                           BACKGROUND  \
# 0  As the winter rain dwarfs against the aged gla...
# 1  :\nThis scene takes place in a dimly lit room ...
# 2  :\nThe intimate sanctuary of Van Gogh's small ...
# 3  Late January evening fills the room in a board...
# 4  :\nThe scene unfolds in the cozy, dimly lit ro...
# 5  :\nThe scene unfolds within the modest, candle...
# 6  We are in a small, modest room, cluttered with...
# 7  May 9, 1873, a humble Dutch residence in The H...
# 8  A gloomy day in London, where the streets are ...
# 9  :\nWe begin in the dimly lit, intimate, and qu...
#
#                              VINCENT VAN GOGH (V.O.) Valence  Arousal  \
# 0  Dearest Theo, your absence in the homestead ha...  -0.100   -0.300
# 1  Dear Theo, Words could hardly express my joy i...   0.900    0.700
# 2  My dear Theo... I found comfort in hearing you...   0.420    0.400
# 3  Dear Theo, \nI find solace in your letter and ...  -0.400    0.400
# 4  Dear Theo, I long to hear of you and Uncle Hei...   0.550    0.150
# 5  "Dear Theo, I am impelled to correspond with y...  -0.050    0.600
# 6  Dear Theo... News from The Hague. You must for...  -0.075    0.175
# 7                                                     -0.800    0.500
# 8  Dearest Theo, it's been a while. I am writing ...   0.000    0.000
# 9  Dear friends, I am overwhelmed by the quiet be...  -0.350    0.700
#
#                  location
# 0  The Hague, Netherlands
# 1  The Hague, Netherlands
# 2  The Hague, Netherlands
# 3  The Hague, Netherlands
# 4  The Hague, Netherlands
# 5  The Hague, Netherlands
# 6  The Hague, Netherlands
# 7  The Hague, Netherlands
# 8                  London
# 9                  London
#
# [10 rows x 21 columns]

# %%
df_locations = pd.DataFrame(df["location"], columns=["location"])
df_locations = pd.DataFrame(pd.Series(df_locations["location"].unique()), columns=["location"])

# %%
import requests
def get_lat_long(place_name):
    # This uses OpenCage Geocoder as an example; replace YOUR_API_KEY with an actual API key
    url = "https://api.opencagedata.com/geocode/v1/json"
    params = {
        'q': place_name,
        'key': ''
    }
    response = requests.get(url, params=params)
    data = response.json()
    if data['results']:
        # Extracting the first result as an example
        lat = data['results'][0]['geometry']['lat']
        lng = data['results'][0]['geometry']['lng']
        return lat, lng
    else:
        return "Coordinates not found", "Coordinates not found"

# %%
import time
def append_lat_long(df, column_name, start_index, end_index):
    # Ensure we don't exceed the DataFrame's bounds
    end_index = min(end_index, len(df))

    # Iterate through the specified range
    for i in range(start_index, end_index):
        if i % 5 == 0:
          print("current",i)
        place_name = df.iloc[i][column_name]
        lat, lng = get_lat_long(place_name)

        # Directly set the values for each row to avoid length mismatch
        df.at[i, 'Latitude'] = lat
        df.at[i, 'Longitude'] = lng

        # Delay between API calls
        time.sleep(1.2)

# %%
df_locations
# Out:
#                    location
# 0    The Hague, Netherlands
# 1                    London
# 2                  Helvoirt
# 3                     Paris
# 4                     Etten
# 5                  Ramsgate
# 6                    Welwyn
# 7                 Isleworth
# 8                 Dordrecht
# 9                 Amsterdam
# 10                   Laeken
# 11             Petit-Wasmes
# 12                  Cuesmes
# 13                 Brussels
# 14      Nuenen, Netherlands
# 15                  Drenthe
# 16                Hoogeveen
# 17            New Amsterdam
# 18                  Antwerp
# 19            Arles, France
# 20           Saintes-Maries
# 21         Belle-Ile-en-Mer
# 22                   Cassis
# 23       Saint-Rémy, France
# 24  Auvers-sur-Oise, France
# 25                  Utrecht

# %%
append_lat_long(df_locations,"location",0,df_locations.size)
# Out:
# current 0
# current 5
# current 10
# current 15
# current 20
# current 25

# %%
df_locations.head(15)
# Out:
#                   location   Latitude  Longitude
# 0   The Hague, Netherlands  52.079984   4.311346
# 1                   London  51.507446  -0.127765
# 2                 Helvoirt  51.633639   5.229065
# 3                    Paris  48.858890   2.320041
# 4                    Etten  51.916117   6.340463
# 5                 Ramsgate  51.333473   1.419648
# 6                   Welwyn  51.828687  -0.214175
# 7                Isleworth  51.468356  -0.326311
# 8                Dordrecht  51.795881   4.677935
# 9                Amsterdam  52.373080   4.892453
# 10                  Laeken  50.883392   4.348713
# 11            Petit-Wasmes  50.404348   3.829706
# 12                 Cuesmes  50.436887   3.924973
# 13                Brussels  50.846557   4.351697
# 14     Nuenen, Netherlands  51.474302   5.549044

# %%
df_locations.head()
# Out:
#                  location   Latitude  Longitude
# 0  The Hague, Netherlands  52.079984   4.311346
# 1                  London  51.507446  -0.127765
# 2                Helvoirt  51.633639   5.229065
# 3                   Paris  48.858890   2.320041
# 4                   Etten  51.916117   6.340463

# %%
df_merged = df.merge(df_locations, how='left', on='location')

# %%
df_merged
# Out:
#            file_name        date origin sender             receiver  \
# 0    001_V-T_001.pdf  1872-08-01    T-H    VvG                  TvG
# 1    002_V-T_002.pdf  1872-12-13    T-H    VvG                  TvG
# 2    003_V-T_003.pdf  1873-01-01    T-H    VvG                  TvG
# 3    004_V-T_004.pdf  1873-01-28    T-H    VvG                  TvG
# 4    005_V-T_005.pdf  1873-03-17    T-H    VvG                  TvG
# ..               ...         ...    ...    ...                  ...
# 857  802_V-W_W19.pdf  1890-01-20    S-R    VvG  Wilhelmina van Gogh
# 858  813_V-W_W20.pdf  1890-02-20    S-R    VvG  Wilhelmina van Gogh
# 859  831_V-W_W21.pdf  1890-05-20    S-R    VvG  Wilhelmina van Gogh
# 860  839_V-W_W22.pdf  1890-06-05  A-s-O    VvG  Wilhelmina van Gogh
# 861  844_V-W_W23.pdf  1890-06-12  A-s-O    VvG  Wilhelmina van Gogh
#
#                                                content  \
# 0    Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1    Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2    Letter 003\nThe Hague, January 1873\nMy dear T...
# 3    Letter 004\nThe Hague, January 28 1873\nDear T...
# 4    Letter 005\nThe Hague, 17 March 1873\nDear The...
# ..                                                 ...
# 857  W19 1\nSaint-Rémy, 20 January 1890\nDear Siste...
# 858  W20 1\nSaint-Rémy, c. 20 February 1890\nMy Dea...
# 859  W21 1\nAuvers, c. 20 May 1890\nMy Dear Sister,...
# 860  W22 1\nAuvers-sur-Oise, 5 June 1890\nMy Dear S...
# 861  Letter W23 1\nAuvers-sur-Oise, c. 12 June 1890...
#
#                                           API_Response  \
# 0    NARRATOR (V.O.)\nIn the period post the depart...
# 1    NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2    NARRATOR (V.O.)\nWe find ourselves in the year...
# 3    NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4    NARRATOR (V.O.)\nWe are venturing into the lif...
# ..                                                 ...
# 857  NARRATOR (V.O.)\nIn this scene, we examine a t...
# 858  NARRATOR (V.O)\nIn February 1890, post-impress...
# 859  NARRATOR (V.O.)\nWe find ourselves in the late...
# 860  NARRATOR (V.O.)\nWe are in the summer of 1890,...
# 861  NARRATOR (V.O.)\nJune 1890. Van Gogh is in Auv...
#
#                                         Scene_Analysis  timestamp  \
# 0    Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1    Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2    Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3    Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4    Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
# ..                                                 ...        ...
# 857  Emotions:\n[Anxiety, Longing, Restlessness, So... 1890-01-20
# 858  Emotions:\n[Anxiety, Solitude, Gratitude, Year... 1890-02-20
# 859  Emotions:\n[Gratitude, Contentment]\n\nCharact... 1890-05-20
# 860  Emotions:\n[Determination, Longing]\n\nCharact... 1890-06-05
# 861  Emotions:\n[Desperation, Burdened, Longing, Ur... 1890-06-12
#
#                                               Emotions  ...  \
# 0                              [Melancholy, Nostalgia]  ...
# 1                                     [Joy, Eagerness]  ...
# 2    [Loneliness, Comfort, Joy, Ambition, Anticipat...  ...
# 3                                      [Longing, Pity]  ...
# 4                            [Anticipation, Nostalgia]  ...
# ..                                                 ...  ...
# 857           [Anxiety, Longing, Restlessness, Solace]  ...
# 858  [Anxiety, Solitude, Gratitude, Yearning, Intri...  ...
# 859                           [Gratitude, Contentment]  ...
# 860                           [Determination, Longing]  ...
# 861          [Desperation, Burdened, Longing, Urgency]  ...
#
#                                              Paintings  \
# 0                         (None provided in the scene)
# 1                                               [None]
# 2                                               [None]
# 3    [None specific, but might be loosely related t...
# 4                                                 None
# ..                                                 ...
# 857                     ['Women in the Olive Orchard']
# 858  ['Branches with Almond Blossoms', 'The Arlesie...
# 859                   [Roses, Violets, Olive Orchards]
# 860  ["Dr. Gachet's Portrait", "The Church at Auvers"]
# 861  ["Dr. Gachet", "Landscape with poplars", "Pota...
#
#                                                Comment  \
# 0    This poignant scene underscores the emotional ...
# 1    This scene is rather significant in understand...
# 2    This scene is both captivating and enlightenin...
# 3    This revealing scene captures a thoughtful and...
# 4    This is a significant moment in van Gogh's lif...
# ..                                                 ...
# 857  In this scene, we see Van Gogh wrestling with ...
# 858  The scene presents a thoughtful and introspect...
# 859  This scene is quite significant and encapsulat...
# 860  The scene under examination showcases the intr...
# 861  The scene is strategically set in June 1890, o...
#
#                                        NARRATOR (V.O.)  \
# 0    In the period post the departure of his brothe...
# 1    In 1872, Vincent van Gogh, known for his vivid...
# 2    We find ourselves in the year 1873, in the pat...
# 3    In the winter of 1873, a young Vincent van Gog...
# 4    We are venturing into the life and mind of Vin...
# ..                                                 ...
# 857  In this scene, we examine a time in Vincent va...
# 858
# 859  We find ourselves in the late spring of 1890. ...
# 860  We are in the summer of 1890, Vincent Van Gogh...
# 861  June 1890. Van Gogh is in Auvers-sur-Oise, liv...
#
#                                             BACKGROUND  \
# 0    As the winter rain dwarfs against the aged gla...
# 1    :\nThis scene takes place in a dimly lit room ...
# 2    :\nThe intimate sanctuary of Van Gogh's small ...
# 3    Late January evening fills the room in a board...
# 4    :\nThe scene unfolds in the cozy, dimly lit ro...
# ..                                                 ...
# 857  :\nThis scene is set in the quintessentially l...
# 858  The rustic room at the asylum, illuminated onl...
# 859  The scene starts in a modest room, bathed in t...
# 860  A small room bathed in the warm hues of the ev...
# 861  A dimly lit room. Shafts of pale morning light...
#
#                                VINCENT VAN GOGH (V.O.)   Valence Arousal  \
# 0    Dearest Theo, your absence in the homestead ha... -0.100000  -0.300
# 1    Dear Theo, Words could hardly express my joy i...  0.900000   0.700
# 2    My dear Theo... I found comfort in hearing you...  0.420000   0.400
# 3    Dear Theo, \nI find solace in your letter and ... -0.400000   0.400
# 4    Dear Theo, I long to hear of you and Uncle Hei...  0.550000   0.150
# ..                                                 ...       ...     ...
# 857  Dear Sister, \nThe Paris I was once entranced ... -0.250000   0.425
# 858  My Dear Sister, \n\nIt appears as though ordin...  0.083333   0.300
# 859  My dear Sister,\nThrongs of unuttered thoughts...  0.850000  -0.300
# 860  June 5th, 1890...Auvers-sur-Oise. My dearest s...  0.200000   0.650
# 861  My dear sister, the desperately swift passing ... -0.600000   0.675
#
#                     location   Latitude  Longitude
# 0     The Hague, Netherlands  52.079984   4.311346
# 1     The Hague, Netherlands  52.079984   4.311346
# 2     The Hague, Netherlands  52.079984   4.311346
# 3     The Hague, Netherlands  52.079984   4.311346
# 4     The Hague, Netherlands  52.079984   4.311346
# ..                       ...        ...        ...
# 857       Saint-Rémy, France  47.636721   4.299632
# 858       Saint-Rémy, France  47.636721   4.299632
# 859       Saint-Rémy, France  47.636721   4.299632
# 860  Auvers-sur-Oise, France  49.070188   2.171869
# 861  Auvers-sur-Oise, France  49.070188   2.171869
#
# [862 rows x 23 columns]

# %%
df_merged[df_merged["file_name"]=="572a.pdf"]
# Out:
#     file_name        date origin sender      receiver  \
# 619  572a.pdf  1889-01-22     Ar    VvG  Paul Gauguin
#
#                                                content  \
# 619  Letter 572a\nArles, c. 22 January 1889\nMy dea...
#
#                                           API_Response  \
# 619  NARRATOR (V.O.)\nAs Vincent van Gogh writes to...
#
#                                         Scene_Analysis  timestamp  \
# 619  Emotions:\n[Isolation, Anxiety]\n\nCharacters:... 1889-01-22
#
#                  Emotions  ...  \
# 619  [Isolation, Anxiety]  ...
#
#                                              Paintings  \
# 619  ["Sunflowers", "La Berceuse (Woman Rocking a C...
#
#                                                Comment  \
# 619  This scene offers valuable insights into Van G...
#
#                                        NARRATOR (V.O.)  \
# 619  As Vincent van Gogh writes to his dear friend ...
#
#                                             BACKGROUND  \
# 619  The camera pans through a vivid, saturated sce...
#
#                                VINCENT VAN GOGH (V.O.) Valence Arousal  \
# 619  My dear friend Gauguin, thank you for your let...    -0.8     0.3
#
#           location   Latitude  Longitude
# 619  Arles, France  43.677622   4.630965
#
# [1 rows x 23 columns]

# %%
df_merged.loc[619, "file_name"] = "900"

# %%
df_merged[df_merged["file_name"]=="572a.pdf"]
# Out:
# Empty DataFrame
# Columns: [file_name, date, origin, sender, receiver, content, API_Response, Scene_Analysis, timestamp, Emotions, Characters, Context, Relevance, Paintings, Comment, NARRATOR (V.O.), BACKGROUND, VINCENT VAN GOGH (V.O.), Valence, Arousal, location, Latitude, Longitude]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_numbers = pd.to_numeric(df_merged["file_name"].apply(lambda x: x[0:3]), errors="coerce")

# %%
for index in df_numbers.index:
    if pd.isnull(df_numbers[index]):
        df_numbers[index] = index+900

print(df_numbers)
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 857    802.0
# 858    813.0
# 859    831.0
# 860    839.0
# 861    844.0
# Name: file_name, Length: 862, dtype: float64

# %%
repeated_numbers = df_numbers.value_counts()[lambda x: x > 1].index.tolist()

repeated_numbers
# Out:
# []

# %%
df_numbers.unique().size
# Out:
# 862

# %%
df_numbers.size
# Out:
# 862

# %%
df_merged["uid"]=df_numbers.apply(lambda x: 50.0+(x/1000))

# %%
df_merged.head()
# Out:
#          file_name        date origin sender receiver  \
# 0  001_V-T_001.pdf  1872-08-01    T-H    VvG      TvG
# 1  002_V-T_002.pdf  1872-12-13    T-H    VvG      TvG
# 2  003_V-T_003.pdf  1873-01-01    T-H    VvG      TvG
# 3  004_V-T_004.pdf  1873-01-28    T-H    VvG      TvG
# 4  005_V-T_005.pdf  1873-03-17    T-H    VvG      TvG
#
#                                              content  \
# 0  Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1  Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2  Letter 003\nThe Hague, January 1873\nMy dear T...
# 3  Letter 004\nThe Hague, January 28 1873\nDear T...
# 4  Letter 005\nThe Hague, 17 March 1873\nDear The...
#
#                                         API_Response  \
# 0  NARRATOR (V.O.)\nIn the period post the depart...
# 1  NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2  NARRATOR (V.O.)\nWe find ourselves in the year...
# 3  NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4  NARRATOR (V.O.)\nWe are venturing into the lif...
#
#                                       Scene_Analysis  timestamp  \
# 0  Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1  Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2  Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3  Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4  Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
#
#                                             Emotions  ...  \
# 0                            [Melancholy, Nostalgia]  ...
# 1                                   [Joy, Eagerness]  ...
# 2  [Loneliness, Comfort, Joy, Ambition, Anticipat...  ...
# 3                                    [Longing, Pity]  ...
# 4                          [Anticipation, Nostalgia]  ...
#
#                                              Comment  \
# 0  This poignant scene underscores the emotional ...
# 1  This scene is rather significant in understand...
# 2  This scene is both captivating and enlightenin...
# 3  This revealing scene captures a thoughtful and...
# 4  This is a significant moment in van Gogh's lif...
#
#                                      NARRATOR (V.O.)  \
# 0  In the period post the departure of his brothe...
# 1  In 1872, Vincent van Gogh, known for his vivid...
# 2  We find ourselves in the year 1873, in the pat...
# 3  In the winter of 1873, a young Vincent van Gog...
# 4  We are venturing into the life and mind of Vin...
#
#                                           BACKGROUND  \
# 0  As the winter rain dwarfs against the aged gla...
# 1  :\nThis scene takes place in a dimly lit room ...
# 2  :\nThe intimate sanctuary of Van Gogh's small ...
# 3  Late January evening fills the room in a board...
# 4  :\nThe scene unfolds in the cozy, dimly lit ro...
#
#                              VINCENT VAN GOGH (V.O.) Valence Arousal  \
# 0  Dearest Theo, your absence in the homestead ha...   -0.10   -0.30
# 1  Dear Theo, Words could hardly express my joy i...    0.90    0.70
# 2  My dear Theo... I found comfort in hearing you...    0.42    0.40
# 3  Dear Theo, \nI find solace in your letter and ...   -0.40    0.40
# 4  Dear Theo, I long to hear of you and Uncle Hei...    0.55    0.15
#
#                  location   Latitude  Longitude     uid
# 0  The Hague, Netherlands  52.079984   4.311346  50.001
# 1  The Hague, Netherlands  52.079984   4.311346  50.002
# 2  The Hague, Netherlands  52.079984   4.311346  50.003
# 3  The Hague, Netherlands  52.079984   4.311346  50.004
# 4  The Hague, Netherlands  52.079984   4.311346  50.005
#
# [5 rows x 24 columns]

# %%
import folium

df_locations['Latitude'] = pd.to_numeric(df_locations['Latitude'], errors='coerce')
df_locations['Longitude'] = pd.to_numeric(df_locations['Longitude'], errors='coerce')

# Filter out rows with NaN in either Latitude or Longitude
df_filtered = df_locations.dropna(subset=['Latitude', 'Longitude'])

# Create a map centered at an average location
map_center = [df_filtered['Latitude'].mean(), df_filtered['Longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=4)

# Add a red dot marker for each coordinate pair
for idx, row in df_filtered.iterrows():
    folium.CircleMarker([row['Latitude'], row['Longitude']],
                        radius=5,
                        color='red',
                        fill=True,
                        fill_color='red',
                        fill_opacity=0.6).add_to(m)

# Save or show the map
m.save('map.html')  # Saves the map to an HTML file
# or use m to display in a Jupyter notebook directly

# %%
df_locations_sorted = df_locations.sort_index()
df_locations_sorted
# Out:
#                    location   Latitude  Longitude
# 0    The Hague, Netherlands  52.079984   4.311346
# 1                    London  51.507446  -0.127765
# 2                  Helvoirt  51.633639   5.229065
# 3                     Paris  48.858890   2.320041
# 4                     Etten  51.916117   6.340463
# 5                  Ramsgate  51.333473   1.419648
# 6                    Welwyn  51.828687  -0.214175
# 7                 Isleworth  51.468356  -0.326311
# 8                 Dordrecht  51.795881   4.677935
# 9                 Amsterdam  52.373080   4.892453
# 10                   Laeken  50.883392   4.348713
# 11             Petit-Wasmes  50.404348   3.829706
# 12                  Cuesmes  50.436887   3.924973
# 13                 Brussels  50.846557   4.351697
# 14      Nuenen, Netherlands  51.474302   5.549044
# 15                  Drenthe  52.906792   6.636842
# 16                Hoogeveen  52.726426   6.493081
# 17            New Amsterdam  40.712728 -74.006015
# 18                  Antwerp  51.221110   4.399708
# 19            Arles, France  43.677622   4.630965
# 20           Saintes-Maries  43.449899   4.427034
# 21         Belle-Ile-en-Mer  47.333940  -3.197291
# 22                   Cassis  43.214036   5.539632
# 23       Saint-Rémy, France  47.636721   4.299632
# 24  Auvers-sur-Oise, France  49.070188   2.171869
# 25                  Utrecht  52.080986   5.127684

# %%
df_merged.tail()
# Out:
#            file_name        date origin sender             receiver  \
# 857  802_V-W_W19.pdf  1890-01-20    S-R    VvG  Wilhelmina van Gogh
# 858  813_V-W_W20.pdf  1890-02-20    S-R    VvG  Wilhelmina van Gogh
# 859  831_V-W_W21.pdf  1890-05-20    S-R    VvG  Wilhelmina van Gogh
# 860  839_V-W_W22.pdf  1890-06-05  A-s-O    VvG  Wilhelmina van Gogh
# 861  844_V-W_W23.pdf  1890-06-12  A-s-O    VvG  Wilhelmina van Gogh
#
#                                                content  \
# 857  W19 1\nSaint-Rémy, 20 January 1890\nDear Siste...
# 858  W20 1\nSaint-Rémy, c. 20 February 1890\nMy Dea...
# 859  W21 1\nAuvers, c. 20 May 1890\nMy Dear Sister,...
# 860  W22 1\nAuvers-sur-Oise, 5 June 1890\nMy Dear S...
# 861  Letter W23 1\nAuvers-sur-Oise, c. 12 June 1890...
#
#                                           API_Response  \
# 857  NARRATOR (V.O.)\nIn this scene, we examine a t...
# 858  NARRATOR (V.O)\nIn February 1890, post-impress...
# 859  NARRATOR (V.O.)\nWe find ourselves in the late...
# 860  NARRATOR (V.O.)\nWe are in the summer of 1890,...
# 861  NARRATOR (V.O.)\nJune 1890. Van Gogh is in Auv...
#
#                                         Scene_Analysis  timestamp  \
# 857  Emotions:\n[Anxiety, Longing, Restlessness, So... 1890-01-20
# 858  Emotions:\n[Anxiety, Solitude, Gratitude, Year... 1890-02-20
# 859  Emotions:\n[Gratitude, Contentment]\n\nCharact... 1890-05-20
# 860  Emotions:\n[Determination, Longing]\n\nCharact... 1890-06-05
# 861  Emotions:\n[Desperation, Burdened, Longing, Ur... 1890-06-12
#
#                                               Emotions  ...  \
# 857           [Anxiety, Longing, Restlessness, Solace]  ...
# 858  [Anxiety, Solitude, Gratitude, Yearning, Intri...  ...
# 859                           [Gratitude, Contentment]  ...
# 860                           [Determination, Longing]  ...
# 861          [Desperation, Burdened, Longing, Urgency]  ...
#
#                                                Comment  \
# 857  In this scene, we see Van Gogh wrestling with ...
# 858  The scene presents a thoughtful and introspect...
# 859  This scene is quite significant and encapsulat...
# 860  The scene under examination showcases the intr...
# 861  The scene is strategically set in June 1890, o...
#
#                                        NARRATOR (V.O.)  \
# 857  In this scene, we examine a time in Vincent va...
# 858
# 859  We find ourselves in the late spring of 1890. ...
# 860  We are in the summer of 1890, Vincent Van Gogh...
# 861  June 1890. Van Gogh is in Auvers-sur-Oise, liv...
#
#                                             BACKGROUND  \
# 857  :\nThis scene is set in the quintessentially l...
# 858  The rustic room at the asylum, illuminated onl...
# 859  The scene starts in a modest room, bathed in t...
# 860  A small room bathed in the warm hues of the ev...
# 861  A dimly lit room. Shafts of pale morning light...
#
#                                VINCENT VAN GOGH (V.O.)   Valence Arousal  \
# 857  Dear Sister, \nThe Paris I was once entranced ... -0.250000   0.425
# 858  My Dear Sister, \n\nIt appears as though ordin...  0.083333   0.300
# 859  My dear Sister,\nThrongs of unuttered thoughts...  0.850000  -0.300
# 860  June 5th, 1890...Auvers-sur-Oise. My dearest s...  0.200000   0.650
# 861  My dear sister, the desperately swift passing ... -0.600000   0.675
#
#                     location   Latitude  Longitude     uid
# 857       Saint-Rémy, France  47.636721   4.299632  50.802
# 858       Saint-Rémy, France  47.636721   4.299632  50.813
# 859       Saint-Rémy, France  47.636721   4.299632  50.831
# 860  Auvers-sur-Oise, France  49.070188   2.171869  50.839
# 861  Auvers-sur-Oise, France  49.070188   2.171869  50.844
#
# [5 rows x 24 columns]

# %%
df_merged.columns
# Out:
# Index(['file_name', 'date', 'origin', 'sender', 'receiver', 'content',
#        'API_Response', 'Scene_Analysis', 'timestamp', 'Emotions', 'Characters',
#        'Context', 'Relevance', 'Paintings', 'Comment', 'NARRATOR (V.O.)',
#        'BACKGROUND', 'VINCENT VAN GOGH (V.O.)', 'Valence', 'Arousal',
#        'location', 'Latitude', 'Longitude', 'uid'],
#       dtype='object')

# %%
df_expanded.head()
# Out:
#          file_name        date origin sender receiver  \
# 0  001_V-T_001.pdf  1872-08-01    T-H    VvG      TvG
# 1  002_V-T_002.pdf  1872-12-13    T-H    VvG      TvG
# 2  003_V-T_003.pdf  1873-01-01    T-H    VvG      TvG
# 3  004_V-T_004.pdf  1873-01-28    T-H    VvG      TvG
# 4  005_V-T_005.pdf  1873-03-17    T-H    VvG      TvG
#
#                                              content  \
# 0  Letter 001\nThe Hague, c. 18 August 1872\nDear...
# 1  Letter 002\nThe Hague, 13 Dec 1872\nDear Theo,...
# 2  Letter 003\nThe Hague, January 1873\nMy dear T...
# 3  Letter 004\nThe Hague, January 28 1873\nDear T...
# 4  Letter 005\nThe Hague, 17 March 1873\nDear The...
#
#                                         API_Response  \
# 0  NARRATOR (V.O.)\nIn the period post the depart...
# 1  NARRATOR (V.O.)\nIn 1872, Vincent van Gogh, kn...
# 2  NARRATOR (V.O.)\nWe find ourselves in the year...
# 3  NARRATOR (V.O.)\nIn the winter of 1873, a youn...
# 4  NARRATOR (V.O.)\nWe are venturing into the lif...
#
#                                       Scene_Analysis  timestamp  \
# 0  Emotions:\n[Melancholy, Nostalgia]\n\nCharacte... 1872-08-01
# 1  Emotions:\n[Joy, Eagerness]\n\nCharacters:\n[V... 1872-12-13
# 2  Emotions:\n[Loneliness, Comfort, Joy, Ambition... 1873-01-01
# 3  Emotions:\n[Longing, Pity]\n\nCharacters:\n[Vi... 1873-01-28
# 4  Emotions:\n[Anticipation, Nostalgia]\n\nCharac... 1873-03-17
#
#                                             Emotions  ...  \
# 0                            [Melancholy, Nostalgia]  ...
# 1                                   [Joy, Eagerness]  ...
# 2  [Loneliness, Comfort, Joy, Ambition, Anticipat...  ...
# 3                                    [Longing, Pity]  ...
# 4                          [Anticipation, Nostalgia]  ...
#
#                                              Context Relevance  \
# 0  This scene is set in the winter of 1872 in Van...       0.8
# 1  This scene reflects a young Vincent van Gogh's...       0.7
# 2  This scene depicts the young Van Gogh in 1873,...       0.8
# 3  This scene describes a time when Van Gogh was ...       0.7
# 4  The scene takes place in the spring of 1873, a...       0.8
#
#                                            Paintings  \
# 0                       (None provided in the scene)
# 1                                             [None]
# 2                                             [None]
# 3  [None specific, but might be loosely related t...
# 4                                               None
#
#                                              Comment  \
# 0  This poignant scene underscores the emotional ...
# 1  This scene is rather significant in understand...
# 2  This scene is both captivating and enlightenin...
# 3  This revealing scene captures a thoughtful and...
# 4  This is a significant moment in van Gogh's lif...
#
#                                      NARRATOR (V.O.)  \
# 0  In the period post the departure of his brothe...
# 1  In 1872, Vincent van Gogh, known for his vivid...
# 2  We find ourselves in the year 1873, in the pat...
# 3  In the winter of 1873, a young Vincent van Gog...
# 4  We are venturing into the life and mind of Vin...
#
#                                           BACKGROUND  \
# 0  As the winter rain dwarfs against the aged gla...
# 1  :\nThis scene takes place in a dimly lit room ...
# 2  :\nThe intimate sanctuary of Van Gogh's small ...
# 3  Late January evening fills the room in a board...
# 4  :\nThe scene unfolds in the cozy, dimly lit ro...
#
#                              VINCENT VAN GOGH (V.O.) Valence  Arousal  \
# 0  Dearest Theo, your absence in the homestead ha...   -0.10    -0.30
# 1  Dear Theo, Words could hardly express my joy i...    0.90     0.70
# 2  My dear Theo... I found comfort in hearing you...    0.42     0.40
# 3  Dear Theo, \nI find solace in your letter and ...   -0.40     0.40
# 4  Dear Theo, I long to hear of you and Uncle Hei...    0.55     0.15
#
#                  location
# 0  The Hague, Netherlands
# 1  The Hague, Netherlands
# 2  The Hague, Netherlands
# 3  The Hague, Netherlands
# 4  The Hague, Netherlands
#
# [5 rows x 21 columns]

# %%
df_pre_final = df_merged[["uid","content","BACKGROUND","NARRATOR (V.O.)","VINCENT VAN GOGH (V.O.)","Context","Comment","Characters","Valence","Arousal","timestamp","Latitude","Longitude","Relevance"]]

# %%
df_final = df_pre_final.rename(columns={"content":"chunk", "BACKGROUND": "background","NARRATOR (V.O.)":"narrator","VINCENT VAN GOGH (V.O.)":"vangogh","Context":"context","Comment":"comment","Characters":"characters","Valence":"valence","Arousal":"arousal","Latitude":"latitude","Longitude":"longitude","Relevance":"relevance"})

# %%
df_final.to_csv("letters_cognitive_dataset_van_gogh.csv")
